# %% [markdown]
# # Informatiehuis Water voor oppervlaktewater kwaliteit analyse met chatgpt
# ## Inhoudsopgave
# 1. Data inlezen en dataframe maken
# 2. Data opschonen
# 3. Exporteren naar Chatgpt als csv
# 4. Antwoord Chatgpt kopieren en analyseren in notebook

# %%
import pandas as pd
import glob
import os

# %% [markdown]
# ## 1. Data inlezen en dataframe maken

# %%
path = 'C:/Users/oostemb/Downloads/IM_Metingen_2022'
all_files = glob.glob(os.path.join(path , "*.csv"))
li = []

for filename in all_files:
    df = pd.read_csv(filename, sep=';',index_col=None, header=0, low_memory=False)
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#         Waterbeheerder.omschrijving Meetobject.namespace Meetobject.code  \
# 0                Wetterskip Fryslan                 NL02       NL02_0002
# 1                Wetterskip Fryslan                 NL02       NL02_0002
# 2                Wetterskip Fryslan                 NL02       NL02_0002
# 3                Wetterskip Fryslan                 NL02       NL02_0002
# 4                Wetterskip Fryslan                 NL02       NL02_0002
# ...                             ...                  ...             ...
# 3489317                         NaN                  NaN             NaN
# 3489318                         NaN                  NaN             NaN
# 3489319                         NaN                  NaN             NaN
# 3489320                         NaN                  NaN             NaN
# 3489321                         NaN                  NaN             NaN
#
#         Meetobject.lokaalID Namespace Monster.Identificatie Monster.lokaalID  \
# 0                    "0002"      NL02                   NaN           "0002"
# 1                    "0002"      NL02                   NaN           "0002"
# 2                    "0002"      NL02                   NaN           "0002"
# 3                    "0002"      NL02                   NaN           "0002"
# 4                    "0002"      NL02                   NaN           "0002"
# ...                     ...       ...                   ...              ...
# 3489317                 NaN       NaN                   NaN              NaN
# 3489318                 NaN       NaN                   NaN              NaN
# 3489319                 NaN       NaN                   NaN              NaN
# 3489320                 NaN       NaN                   NaN              NaN
# 3489321                 NaN       NaN                   NaN              NaN
#
#         MonsterCompartiment.code MonsterCompartiment.omschrijving  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ...                          ...                              ...
# 3489317                      NaN                              NaN
# 3489318                      NaN                              NaN
# 3489319                      NaN                              NaN
# 3489320                      NaN                              NaN
# 3489321                      NaN                              NaN
#
#          Orgaan.code  ...  Compartiment.omschrijving  \
# 0                NaN  ...           Oppervlaktewater
# 1                NaN  ...           Oppervlaktewater
# 2                NaN  ...           Oppervlaktewater
# 3                NaN  ...           Oppervlaktewater
# 4                NaN  ...           Oppervlaktewater
# ...              ...  ...                        ...
# 3489317          NaN  ...                        NaN
# 3489318          NaN  ...                        NaN
# 3489319          NaN  ...                        NaN
# 3489320          NaN  ...                        NaN
# 3489321          NaN  ...                        NaN
#
#          Waardebewerkingsmethode.code  Waardebewerkingsmethode.omschrijving  \
# 0                                 NVT                   Niet van toepassing
# 1                                 NVT                   Niet van toepassing
# 2                                 NVT                   Niet van toepassing
# 3                                 NVT                   Niet van toepassing
# 4                                 NVT                   Niet van toepassing
# ...                               ...                                   ...
# 3489317                           NaN                                   NaN
# 3489318                           NaN                                   NaN
# 3489319                           NaN                                   NaN
# 3489320                           NaN                                   NaN
# 3489321                           NaN                                   NaN
#
#         Limietsymbool Numeriekewaarde Alfanumeriekewaarde  \
# 0                 NaN          130.00                 NaN
# 1                 NaN          400.00                 NaN
# 2                 NaN            7.30                 NaN
# 3                 NaN            0.48                 NaN
# 4                 NaN            0.08                 NaN
# ...               ...             ...                 ...
# 3489317           NaN             NaN                 NaN
# 3489318           NaN             NaN                 NaN
# 3489319           NaN             NaN                 NaN
# 3489320           NaN             NaN                 NaN
# 3489321           NaN             NaN                 NaN
#
#          Kwaliteitsoordeel.code  Rapportagejaar  Meetjaar  \
# 0                          "00"          2023.0    2022.0
# 1                          "00"          2023.0    2022.0
# 2                          "00"          2023.0    2022.0
# 3                          "00"          2023.0    2022.0
# 4                          "00"          2023.0    2022.0
# ...                         ...             ...       ...
# 3489317                     NaN             NaN       NaN
# 3489318                     NaN             NaN       NaN
# 3489319                     NaN             NaN       NaN
# 3489320                     NaN             NaN       NaN
# 3489321                     NaN             NaN       NaN
#
#         ,Waterbeheerder.omschrijving,Numeriekewaarde,Parameter.omschrijving,Monsterophaaldatum
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 3489317  3018760,Waterschap Hollandse Delta,0.003,zilve...
# 3489318  3018761,Waterschap Hollandse Delta,1.3,zink,20...
# 3489319  3018762,Waterschap Hollandse Delta,0.05,zirkon...
# 3489320  3018764,Waterschap Hollandse Delta,11.5,zuurst...
# 3489321  3018765,Waterschap Hollandse Delta,94.0,zuurst...
#
# [3489322 rows x 63 columns]

# %% [markdown]
# ## 2.1 Data opschonen
# ## Allemaal waterschappen die niet in de provincie Zuid-Holland zitten. Eerst opschonen.

# %%
waterschappen_pzh = ['Hoogheemraadschap De Stichtse Rijnlanden', 'Waterschap Amstel Gooi en Vecht','Hoogheemraadschap van Rijnland','Hoogheemraadschap van Delfland','Hoogheemraadschap van Schieland en Krimpenerwaard', 'Waterschap Hollandse Delta']
mask = frame['Waterbeheerder.omschrijving'].isin(waterschappen_pzh)
pzh_metingen = frame[mask]

# %%
pzh_metingen
# Out:
#              Waterbeheerder.omschrijving Meetobject.namespace Meetobject.code  \
# 43284    Waterschap Amstel Gooi en Vecht                 NL11     NL11_ABC012
# 43285    Waterschap Amstel Gooi en Vecht                 NL11     NL11_ABC012
# 43286    Waterschap Amstel Gooi en Vecht                 NL11     NL11_ABC012
# 43287    Waterschap Amstel Gooi en Vecht                 NL11     NL11_ABC012
# 43288    Waterschap Amstel Gooi en Vecht                 NL11     NL11_ABC012
# ...                                  ...                  ...             ...
# 3018761       Waterschap Hollandse Delta                 NL40   NL40_YOP_1406
# 3018762       Waterschap Hollandse Delta                 NL40   NL40_YOP_1406
# 3018763       Waterschap Hollandse Delta                 NL40   NL40_YOP_1406
# 3018764       Waterschap Hollandse Delta                 NL40   NL40_YOP_1406
# 3018765       Waterschap Hollandse Delta                 NL40   NL40_YOP_1406
#
#         Meetobject.lokaalID Namespace Monster.Identificatie Monster.lokaalID  \
# 43284              "ABC012"      NL11         NL11_WP647191         "ABC012"
# 43285              "ABC012"      NL11         NL11_WP647191         "ABC012"
# 43286              "ABC012"      NL11         NL11_WP647191         "ABC012"
# 43287              "ABC012"      NL11         NL11_WP647191         "ABC012"
# 43288              "ABC012"      NL11         NL11_WP647191         "ABC012"
# ...                     ...       ...                   ...              ...
# 3018761          "YOP_1406"      NL40         NL40_C-375966       "YOP_1406"
# 3018762          "YOP_1406"      NL40         NL40_C-375966       "YOP_1406"
# 3018763          "YOP_1406"      NL40         NL40_C-375966       "YOP_1406"
# 3018764          "YOP_1406"      NL40         NL40_C-375966       "YOP_1406"
# 3018765          "YOP_1406"      NL40         NL40_C-375966       "YOP_1406"
#
#         MonsterCompartiment.code MonsterCompartiment.omschrijving  \
# 43284                        NaN                              NaN
# 43285                        NaN                              NaN
# 43286                        NaN                              NaN
# 43287                        NaN                              NaN
# 43288                        NaN                              NaN
# ...                          ...                              ...
# 3018761                       OW                 Oppervlaktewater
# 3018762                       OW                 Oppervlaktewater
# 3018763                       OW                 Oppervlaktewater
# 3018764                       OW                 Oppervlaktewater
# 3018765                       OW                 Oppervlaktewater
#
#          Orgaan.code  ...  Compartiment.omschrijving  \
# 43284            NaN  ...           Oppervlaktewater
# 43285            NaN  ...           Oppervlaktewater
# 43286            NaN  ...           Oppervlaktewater
# 43287            NaN  ...           Oppervlaktewater
# 43288            NaN  ...           Oppervlaktewater
# ...              ...  ...                        ...
# 3018761          NaN  ...           Oppervlaktewater
# 3018762          NaN  ...           Oppervlaktewater
# 3018763          NaN  ...           Oppervlaktewater
# 3018764          NaN  ...           Oppervlaktewater
# 3018765          NaN  ...           Oppervlaktewater
#
#          Waardebewerkingsmethode.code  Waardebewerkingsmethode.omschrijving  \
# 43284                             NVT                   Niet van toepassing
# 43285                             NVT                   Niet van toepassing
# 43286                             NVT                   Niet van toepassing
# 43287                             NVT                   Niet van toepassing
# 43288                             NVT                   Niet van toepassing
# ...                               ...                                   ...
# 3018761                           NVT                   Niet van toepassing
# 3018762                           NVT                   Niet van toepassing
# 3018763                           NVT                   Niet van toepassing
# 3018764                           NVT                   Niet van toepassing
# 3018765                           NVT                   Niet van toepassing
#
#         Limietsymbool Numeriekewaarde Alfanumeriekewaarde  \
# 43284               <            5.00                 NaN
# 43285             NaN           81.00                 NaN
# 43286             NaN            9.50                 NaN
# 43287               <            0.50                 NaN
# 43288               <            0.50                 NaN
# ...               ...             ...                 ...
# 3018761           NaN            1.30                 NaN
# 3018762             <            0.05                 NaN
# 3018763           NaN            7.80                 NaN
# 3018764           NaN           11.50                 NaN
# 3018765           NaN           94.00                 NaN
#
#          Kwaliteitsoordeel.code  Rapportagejaar  Meetjaar  \
# 43284                      "00"          2023.0    2022.0
# 43285                      "00"          2023.0    2022.0
# 43286                      "00"          2023.0    2022.0
# 43287                      "00"          2023.0    2022.0
# 43288                      "00"          2023.0    2022.0
# ...                         ...             ...       ...
# 3018761                    "00"          2023.0    2022.0
# 3018762                    "00"          2023.0    2022.0
# 3018763                    "00"          2023.0    2022.0
# 3018764                    "00"          2023.0    2022.0
# 3018765                    "00"          2023.0    2022.0
#
#         ,Waterbeheerder.omschrijving,Numeriekewaarde,Parameter.omschrijving,Monsterophaaldatum
# 43284                                                  NaN
# 43285                                                  NaN
# 43286                                                  NaN
# 43287                                                  NaN
# 43288                                                  NaN
# ...                                                    ...
# 3018761                                                NaN
# 3018762                                                NaN
# 3018763                                                NaN
# 3018764                                                NaN
# 3018765                                                NaN
#
# [1103746 rows x 63 columns]

# %%
pzh_metingen.columns
# Out:
# Index(['Waterbeheerder.omschrijving', 'Meetobject.namespace',
#        'Meetobject.code', 'Meetobject.lokaalID', 'Namespace',
#        'Monster.Identificatie', 'Monster.lokaalID', 'MonsterCompartiment.code',
#        'MonsterCompartiment.omschrijving', 'Orgaan.code',
#        'Orgaan.omschrijving', 'Organisme.naam', 'Bemonsteringsapparaat.code',
#        'Bemonsteringsapparaat.omschrijving', 'Monsterophaaldatum',
#        'Monsterophaaltijd', 'GeometriePunt.X', 'GeometriePunt.Y',
#        'meetwaardeid', 'Meetwaarde.lokaalID', 'Resultaatdatum', 'Begindatum',
#        'Begintijd', 'Einddatum', 'Eindtijd', 'Typering.code',
#        'Typering.omschrijving', 'Grootheid.code', 'Grootheid.omschrijving',
#        'Parameter.groep', 'Parameter.code', 'Parameter.omschrijving',
#        'Parameter.CASnummer', 'Biotaxon.naam', 'Eenheid.code',
#        'Eenheid.omschrijving', 'Hoedanigheid.code',
#        'Hoedanigheid.omschrijving', 'Levensstadium.code',
#        'Levensstadium.omschrijving', 'Lengteklasse.code',
#        'Lengteklasse.omschrijving', 'Geslacht.code', 'Geslacht.omschrijving',
#        'Verschijningsvorm.code', 'Verschijningsvorm.omschrijving',
#        'Levensvorm.code', 'Levensvorm.omschrijving', 'Gedrag.code',
#        'Gedrag.omschrijving', 'AnalyseCompartiment.code',
#        'AnalyseCompartiment.omschrijving', 'Compartiment.code',
#        'Compartiment.omschrijving', 'Waardebewerkingsmethode.code',
#        'Waardebewerkingsmethode.omschrijving', 'Limietsymbool',
#        'Numeriekewaarde', 'Alfanumeriekewaarde', 'Kwaliteitsoordeel.code',
#        'Rapportagejaar', 'Meetjaar',
#        ',Waterbeheerder.omschrijving,Numeriekewaarde,Parameter.omschrijving,Monsterophaaldatum'],
#       dtype='object')

# %% [markdown]
# ## Teveel kolommen. Bewaar alleen degene die ik nodig heb.

# %%
pzh_useful = pzh_metingen[['Waterbeheerder.omschrijving', 'Numeriekewaarde', 'Parameter.omschrijving', 'Monsterophaaldatum']]

# %%
pzh_useful
# Out:
#              Waterbeheerder.omschrijving  Numeriekewaarde  \
# 43284    Waterschap Amstel Gooi en Vecht             5.00
# 43285    Waterschap Amstel Gooi en Vecht            81.00
# 43286    Waterschap Amstel Gooi en Vecht             9.50
# 43287    Waterschap Amstel Gooi en Vecht             0.50
# 43288    Waterschap Amstel Gooi en Vecht             0.50
# ...                                  ...              ...
# 3018761       Waterschap Hollandse Delta             1.30
# 3018762       Waterschap Hollandse Delta             0.05
# 3018763       Waterschap Hollandse Delta             7.80
# 3018764       Waterschap Hollandse Delta            11.50
# 3018765       Waterschap Hollandse Delta            94.00
#
#         Parameter.omschrijving Monsterophaaldatum
# 43284              chlorofyl-a                NaN
# 43285                  calcium                NaN
# 43286              chlorofyl-a                NaN
# 43287              chlorofyl-a                NaN
# 43288              chlorofyl-a                NaN
# ...                        ...                ...
# 3018761                   zink         2022-12-20
# 3018762              zirkonium         2022-12-20
# 3018763                    NaN         2022-12-20
# 3018764               zuurstof         2022-12-20
# 3018765               zuurstof         2022-12-20
#
# [1103746 rows x 4 columns]

# %% [markdown]
# ## NaN Waardes. Lege rijen, heb ik niks aan, ook opschonen.

# %%
pzh_useful.isnull().sum(axis = 0)
# Out:
# Waterbeheerder.omschrijving         0
# Numeriekewaarde                  5926
# Parameter.omschrijving         332930
# Monsterophaaldatum             438267
# dtype: int64

# %%
pzh_useful_no_na = pzh_useful.dropna()

# %%
pzh_useful_no_na
# Out:
#             Waterbeheerder.omschrijving  Numeriekewaarde  \
# 71984    Hoogheemraadschap van Rijnland            8.600
# 71985    Hoogheemraadschap van Rijnland            1.860
# 71986    Hoogheemraadschap van Rijnland            1.900
# 71987    Hoogheemraadschap van Rijnland            3.800
# 71988    Hoogheemraadschap van Rijnland            0.234
# ...                                 ...              ...
# 3018760      Waterschap Hollandse Delta            0.003
# 3018761      Waterschap Hollandse Delta            1.300
# 3018762      Waterschap Hollandse Delta            0.050
# 3018764      Waterschap Hollandse Delta           11.500
# 3018765      Waterschap Hollandse Delta           94.000
#
#          Parameter.omschrijving Monsterophaaldatum
# 71984                  zuurstof         2022-01-25
# 71985    som nitraat en nitriet         2022-01-25
# 71986         stikstof Kjeldahl         2022-01-25
# 71987           stikstof totaal         2022-01-25
# 71988                  ammonium         2022-01-25
# ...                         ...                ...
# 3018760                  zilver         2022-12-20
# 3018761                    zink         2022-12-20
# 3018762               zirkonium         2022-12-20
# 3018764                zuurstof         2022-12-20
# 3018765                zuurstof         2022-12-20
#
# [390626 rows x 4 columns]

# %%
filepath= 'C:/Users/oostemb/Downloads/IM_Metingen_2022/pzh_krw_useful.csv'
pzh_useful_no_na.to_csv(filepath)

# %% [markdown]
# # 3. Exporteren en uploaden naar chatgpt.

# %%
data = pzh_useful_no_na

# %% [markdown]
# ## Vraag: Voer en visualiseer een gedetailleerde grafische analyse uit hoe Waterbeheerder.omschrijving, Monsterophaaldatum de Parameter.omschrijving en Numeriekewaarde beïnvloeden?

# %% [markdown]
# ## Antwoord:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Convert 'Monsterophaaldatum' to datetime
data['Monsterophaaldatum'] = pd.to_datetime(data['Monsterophaaldatum'])

# Selecting a subset of parameters for visualization to avoid clutter
selected_parameters = data['Parameter.omschrijving'].value_counts().index[:5]

# Filter data for selected parameters
filtered_data = data[data['Parameter.omschrijving'].isin(selected_parameters)]

# Time series plot for different parameters
plt.figure(figsize=(15, 7))
sns.lineplot(x='Monsterophaaldatum', y='Numeriekewaarde', hue='Parameter.omschrijving', data=filtered_data)
plt.title('Time Series of Numerical Values for Different Parameters')
plt.xlabel('Sample Collection Date')
plt.ylabel('Numerical Value')
plt.xticks(rotation=45)
plt.legend(title='Parameter Description')
plt.tight_layout()
plt.show()

# Box plot for different water management authorities
plt.figure(figsize=(15, 7))
sns.boxplot(x='Waterbeheerder.omschrijving', y='Numeriekewaarde', data=filtered_data)
plt.title('Distribution of Numerical Values Across Water Management Authorities')
plt.xlabel('Water Management Authority')
plt.ylabel('Numerical Value')
plt
# Out:
# C:\Users\oostemb\AppData\Local\Temp\ipykernel_13084\2787303591.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Monsterophaaldatum'] = pd.to_datetime(data['Monsterophaaldatum'])
# <module 'matplotlib.pyplot' from 'C:\\Users\\oostemb\\AppData\\Local\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Identify the top 5 most common parameter descriptions
top_5_parameters = data['Parameter.omschrijving'].value_counts().head(5).index

# Filter data for the top 5 parameters
top_5_data = data[data['Parameter.omschrijving'].isin(top_5_parameters)]

# Plot time series for the top 5 parameters and their corresponding numerical values
plt.figure(figsize=(15, 10))

for parameter in top_5_parameters:
    parameter_subset = top_5_data[top_5_data['Parameter.omschrijving'] == parameter]
    sns.lineplot(x='Monsterophaaldatum', y='Numeriekewaarde', data=parameter_subset, label=parameter)

plt.title('Time Series Analysis of Top 5 Parameters and Their Numerical Values')
plt.xlabel('Sample Collection Date')
plt.ylabel('Numerical Value')
plt.xticks(rotation=45)
plt.legend(title='Parameter Description')
plt.tight_layout()

# Show the plot
plt.show()

# %%
data
# Out:
#             Waterbeheerder.omschrijving  Numeriekewaarde  \
# 71984    Hoogheemraadschap van Rijnland            8.600
# 71985    Hoogheemraadschap van Rijnland            1.860
# 71986    Hoogheemraadschap van Rijnland            1.900
# 71987    Hoogheemraadschap van Rijnland            3.800
# 71988    Hoogheemraadschap van Rijnland            0.234
# ...                                 ...              ...
# 3018760      Waterschap Hollandse Delta            0.003
# 3018761      Waterschap Hollandse Delta            1.300
# 3018762      Waterschap Hollandse Delta            0.050
# 3018764      Waterschap Hollandse Delta           11.500
# 3018765      Waterschap Hollandse Delta           94.000
#
#          Parameter.omschrijving Monsterophaaldatum Monsterophaaltijd  \
# 71984                  zuurstof         2022-01-25          14:25:43
# 71985    som nitraat en nitriet         2022-01-25          14:25:43
# 71986         stikstof Kjeldahl         2022-01-25          14:25:43
# 71987           stikstof totaal         2022-01-25          14:25:43
# 71988                  ammonium         2022-01-25          14:25:43
# ...                         ...                ...               ...
# 3018760                  zilver         2022-12-20          15:46:00
# 3018761                    zink         2022-12-20          15:46:00
# 3018762               zirkonium         2022-12-20          15:46:00
# 3018764                zuurstof         2022-12-20          15:46:00
# 3018765                zuurstof         2022-12-20          15:46:00
#
#         Meetobject.code
# 71984       NL13_OW0433
# 71985       NL13_OW0433
# 71986       NL13_OW0433
# 71987       NL13_OW0433
# 71988       NL13_OW0433
# ...                 ...
# 3018760   NL40_YOP_1406
# 3018761   NL40_YOP_1406
# 3018762   NL40_YOP_1406
# 3018764   NL40_YOP_1406
# 3018765   NL40_YOP_1406
#
# [384873 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'Monsterophaaldatum' and 'Monsterophaaltijd' to datetime
data['Monsterophaaldatum'] = pd.to_datetime(data['Monsterophaaldatum'])
data['Monsterophaaltijd'] = pd.to_datetime(data['Monsterophaaltijd'], format='%H:%M:%S').dt.time

# Creating a combined datetime column for easier plotting
data['MonsterophaalDateTime'] = pd.to_datetime(data['Monsterophaaldatum'].astype(str) + ' ' + data['Monsterophaaltijd'].astype(str))

# Plot 1: Distribution of 'Numeriekewaarde' for different 'Parameter.omschrijving'
plt.figure(figsize=(15, 6))
sns.boxplot(x='Parameter.omschrijving', y='Numeriekewaarde', data=data)
plt.xticks(rotation=45)
plt.title('Distribution of Numeriekewaarde for different Parameters')
plt.xlabel('Parameter Omschrijving')
plt.ylabel('Numeriekewaarde')
plt.show()

# Plot 2: Relationship between 'MonsterophaalDateTime' and 'Numeriekewaarde' for different parameters
# Selecting a few parameters for demonstration
sample_parameters = data['Parameter.omschrijving'].unique()[:5]
sample_data = data[data['Parameter.omschrijving'].isin(sample_parameters)]

plt.figure(figsize=(15, 6))
sns.lineplot(x='MonsterophaalDateTime', y='Numeriekewaarde', hue='Parameter.omschrijving', data=sample_data)
plt.xticks(rotation=45)
plt.title('Numeriekewaarde over Time for Selected Parameters')
plt.xlabel('MonsterophaalDateTime')
plt.ylabel('Numeriekewaarde')
plt.show()

# Plot 3: Influence of 'Waterbeheerder.omschrijving' and 'Meetobject.code' on 'Numeriekewaarde'
# Due to potentially large number of categories, we'll visualize using a sample
sample_waterbeheerders = data['Waterbeheerder.omschrijving'].unique()[:5]
sample_meetobjecten = data['Meetobject.code'].unique()[:5]
sample_data_2 = data[(data['Waterbeheerder.omschrijving'].isin(sample_waterbeheerders)) & 
                     (data['Meetobject.code'].isin(sample_meetobjecten))]

plt.figure(figsize=(15, 6))
sns.barplot(x='Waterbeheerder.omschrijving', y='Numeriekewaarde', hue='Meetobject.code', data=sample_data_2)
plt.xticks(rotation=45)
plt.title('Influence of Waterbeheerder and Meetobject on Numeriekewaarde')
plt.xlabel('Waterbeheerder Omschrijving')
plt.ylabel('Numeriekewaarde')
plt.show()
# Out:
# C:\Users\oostemb\AppData\Local\Temp\ipykernel_13084\671574532.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Monsterophaaldatum'] = pd.to_datetime(data['Monsterophaaldatum'])
# C:\Users\oostemb\AppData\Local\Temp\ipykernel_13084\671574532.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Monsterophaaltijd'] = pd.to_datetime(data['Monsterophaaltijd'], format='%H:%M:%S').dt.time
# C:\Users\oostemb\AppData\Local\Temp\ipykernel_13084\671574532.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['MonsterophaalDateTime'] = pd.to_datetime(data['Monsterophaaldatum'].astype(str) + ' ' + data['Monsterophaaltijd'].astype(str))

# %%
# Identify the largest waterbeheerder based on the number of records
largest_waterbeheerder = data['Waterbeheerder.omschrijving'].value_counts().idxmax()

# Filter the data for the largest waterbeheerder and the top 5 parameters
data_largest_waterbeheerder = data_top_5_params[data_top_5_params['Waterbeheerder.omschrijving'] == largest_waterbeheerder]

# Filename for the PDF report
pdf_filename = f"Waterbeheerder_{largest_waterbeheerder}_Report.pdf".replace(" ", "_")
pdf_path = f"/mnt/data/{pdf_filename}"

# Create a PDF report for the largest waterbeheerder
with matplotlib.backends.backend_pdf.PdfPages(pdf_path) as pdf:
    for parameter in top_5_parameters:
        param_data = data_largest_waterbeheerder[data_largest_waterbeheerder['Parameter.omschrijving'] == parameter]
        plt.figure(figsize=(10, 6))
        sns.lineplot(x='MonsterophaalDateTime', y='Numeriekewaarde', data=param_data)
        plt.title(f'{largest_water
